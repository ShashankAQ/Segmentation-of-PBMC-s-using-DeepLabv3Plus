# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashankAQ/Segmentation-of-PBMC-s-using-DeepLabv3Plus/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/VainF/DeepLabV3Plus-Pytorch.git
# Out:
# Cloning into 'DeepLabV3Plus-Pytorch'...
# remote: Enumerating objects: 705, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 705 (delta 25), reused 14 (delta 14), pack-reused 668 (from 2)
# Receiving objects: 100% (705/705), 8.26 MiB | 13.22 MiB/s, done.
# Resolving deltas: 100% (380/380), done.

# %%
# %cd /content/DeepLabV3Plus-Pytorch
# Out:
# /content/DeepLabV3Plus-Pytorch

# %%
# !pip install -r /content/DeepLabV3Plus-Pytorch/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 25.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 43.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.0 MB/s eta 0:00:00
# ...

# %%
# !python main.py \
  --model deeplabv3plus_resnet101 \
  --gpu_id 0 \
  --year 2012 \
  --crop_val \
  --lr 0.0005 \
  --crop_size 513 \
  --batch_size 8 \
  --output_stride 16 \
  --data_root "/content/drive/MyDrive/VOC_Dataset" \
  --ckpt "/content/drive/MyDrive/model.pth" \
  --loss_type focal_loss \
  --lr_policy poly \
  --total_itrs 3600 \
  --save_val_results \
  --random_seed 42
# Out:
# Device: cuda
# Dataset: voc, Train set: 197, Val set: 160
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# 100% 170M/170M [00:00<00:00, 335MB/s]
# Model restored from /content/drive/MyDrive/great_over_load.pth
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# Epoch 1, Itrs 10/3600, Loss=0.011918
# Unique labels in batch: tensor([0, 1], device='cuda:0')
# ...

# %% [markdown]
# **Evaluating the trained model**

# %%
# !python main.py --model deeplabv3plus_resnet101 \
    --gpu_id 0 \
    --year 2012 \
    --crop_val \
    --lr 0.01 \
    --crop_size 513 \
    --batch_size 4 \
    --output_stride 16 \
    --data_root "/content/drive/MyDrive/VOC_Dataset2" \
    --ckpt "/content/DeepLabV3Plus-Pytorch/checkpoints/latest_deeplabv3plus_resnet101_voc_os16.pth" \
    --test_only \
    --save_val_results
# Out:
# Device: cuda
# Dataset: voc, Train set: 90, Val set: 6
# Model restored from /content/DeepLabV3Plus-Pytorch/checkpoints/latest_deeplabv3plus_resnet101_voc_os16.pth
# 2it [00:02,  1.16s/it]
# /content/DeepLabV3Plus-Pytorch/metrics/stream_metrics.py:66: RuntimeWarning: invalid value encountered in divide
#   acc_cls = np.diag(hist) / hist.sum(axis=1)
# /content/DeepLabV3Plus-Pytorch/metrics/stream_metrics.py:68: RuntimeWarning: invalid value encountered in divide
#   iu = np.diag(hist) / (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
#
# Overall Acc: 0.960420
# Mean Acc: 0.722404
# FreqW Acc: 0.922757
# Mean IoU: 0.700466

# %% [markdown]
# **Downloading the checkpoints folder**

# %%
import shutil
from google.colab import files


shutil.make_archive('/content/checkpoints', 'zip', '/content/DeepLabV3Plus-Pytorch/checkpoints')

files.download('/content/checkpoints.zip')

# %% [markdown]
# **Moving the trained models to drive**

# %%
from google.colab import drive
import shutil


drive.mount('/content/drive')


src_path = '/content/DeepLabV3Plus-Pytorch/checkpoints/latest_deeplabv3plus_resnet101_voc_os16.pth'
dst_path = '/content/drive/MyDrive/model.pth'

shutil.copy(src_path, dst_path)

print(" File copied to Google Drive successfully!")

# %%
# !nvidia-smi
# Out:
# Sun Mar 30 14:10:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
